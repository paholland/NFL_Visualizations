# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Store CSV into DataFrame - Extract

# %%
csv_file1 = "./Resources/passer.csv"
data_df1 = pd.read_csv(csv_file1)
data_df1.head()
# Out:
#      passId    playId  teamId  playerId passPosition passOutcomes  \
# 0  15154145  15088467    4500  20140062           QB     complete
# 1  15154146  15088472    4500  20140062           QB     complete
# 2  15154147  15088473    4500  20140062           QB     complete
# 3  15154148  15088474    4500  20140062           QB   incomplete
# 4  15154149  15088475    4500  20140062           QB   incomplete
#
#   passDirection passDepth  passLength  passAtt  passComp  passTd  passInt  \
# 0          left     short           0        1         1       0        0
# 1        middle     short          -1        1         1       0        0
# 2         right     short          -2        1         1       0        0
# 3        middle     short           5        1         0       0        0
# 4          left     short           6        1         0       0        0
#
#    passIntTd  passSack  passSackYds  passHit  passDef  passNull
# ...

# %%
data_df1.columns
# Out:
# Index(['passId', 'playId', 'teamId', 'playerId', 'passPosition',
#        'passOutcomes', 'passDirection', 'passDepth', 'passLength', 'passAtt',
#        'passComp', 'passTd', 'passInt', 'passIntTd', 'passSack', 'passSackYds',
#        'passHit', 'passDef', 'passNull'],
#       dtype='object')

# %%
#statistical summary of numerical columns
data_df1.describe()
# Out:
#              passId        playId         teamId      playerId     passLength  \
# count  3.972650e+05  3.972650e+05  397265.000000  3.972650e+05  397265.000000
# mean   7.926471e+06  7.760735e+06    2521.278001  2.006086e+07       7.082945
# std    4.548197e+06  4.574535e+06    1378.035734  6.395508e+04       9.815828
# min    2.000010e+05  3.000000e+00     200.000000  1.985028e+07     -99.000000
# 25%    4.207590e+06  4.017573e+06    1400.000000  2.002008e+07       0.000000
# 50%    8.209443e+06  8.019945e+06    2510.000000  2.005025e+07       4.000000
# 75%    1.220451e+07  1.200938e+07    3430.000000  2.011004e+07      11.000000
# max    1.515422e+07  1.508862e+07    5110.000000  2.019117e+07      78.000000
#
#              passAtt       passComp         passTd        passInt  \
# count  397265.000000  397265.000000  397265.000000  397265.000000
# mean        0.936506       0.562718       0.038350       0.025187
# std         0.243850       0.496052       0.192039       0.156694
# ...

# %%
csv_file2 = "./Resources/draft.csv"
data_df2 = pd.read_csv(csv_file2)
data_df2.head()
# Out:
#    playerId  draft  round  pick  draftTradeValue draftTeam position  teamId  \
# 0  19770001   1977    1.0     1           3000.0        TB       RB    4900
# 1  19770002   1977    1.0     2           2600.0       DAL       RB    1200
# 2  19770003   1977    1.0     3           2200.0       CIN       DE     920
# 3  19770004   1977    1.0     4           1800.0       NYJ       OT    3430
# 4  19770005   1977    1.0     5           1700.0       NYG       DE    3410
#
#   nameFirst nameLast  ...         dob  ageAtDraft  \
# 0     Ricky     Bell  ...  1955-04-08   22.084932
# 1      Tony  Dorsett  ...  1954-04-07   23.087671
# 2     Eddie  Edwards  ...  1954-04-25   23.038356
# 3    Marvin   Powell  ...  1955-08-30   21.690411
# 4      Gary    Jeter  ...  1955-01-24   22.287671
#
#                                     playerProfileUrl     homeCity homeState  \
# 0  http://www.nfl.com/player/RickyBell/2509366/pr...      Houston        TX
# ...

# %%
data_df2.columns
# Out:
# Index(['playerId', 'draft', 'round', 'pick', 'draftTradeValue', 'draftTeam',
#        'position', 'teamId', 'nameFirst', 'nameLast', 'nameFull', 'collegeId',
#        'nflId', 'combineId', 'college', 'heightInches', 'weight', 'dob',
#        'ageAtDraft', 'playerProfileUrl', 'homeCity', 'homeState',
#        'homeCountry', 'highSchool', 'hsCity', 'hsState', 'hsCountry'],
#       dtype='object')

# %%
#statistical summary of numerical columns
data_df2.describe()
# Out:
#            playerId         draft         round          pick  \
# count  1.214000e+04  12140.000000  11879.000000  12140.000000
# mean   1.996659e+07   1996.644728      5.247075    144.330890
# std    1.258921e+05     12.590873      2.985651     86.461787
# min    1.977000e+07   1977.000000      1.000000      1.000000
# 25%    1.986003e+07   1986.000000      3.000000     71.000000
# 50%    1.996003e+07   1996.000000      5.000000    141.000000
# 75%    2.008004e+07   2008.000000      7.000000    212.000000
# max    2.019025e+07   2019.000000     12.000000    336.000000
#
#        draftTradeValue        teamId     collegeId         nflId  \
# count     12140.000000  12140.000000  12140.000000  1.088900e+04
# mean        215.491507   2558.886326  54597.958320  2.371373e+06
# std         411.552343   1382.300189  26104.543796  5.631940e+05
# min           0.000000    200.000000      1.000000  1.820000e+02
# 25%           6.600000   1400.000000  32611.000000  2.501586e+06
# ...

# %%
csv_file3 = "./Resources/salaries2016.csv"
data_df3= pd.read_csv(csv_file3)
data_df3.head()
# Out:
#     Rk                       Player Pos   Tm    Cap Hit
# 0  1.0  Ben Roethlisberger\RoetBe00  QB  PIT  $23950000
# 1  2.0           Matt Ryan\RyanMa00  QB  ATL  $23750000
# 2  3.0          Joe Flacco\FlacJo00  QB  BAL  $22550000
# 3  4.0        Kirk Cousins\CousKi00  QB  WAS  $19953000
# 4  5.0          Cam Newton\NewtCa00  QB  CAR  $19500000

# %%
data_df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Tm', 'Cap Hit'], dtype='object')

# %%
csv_file4 = "./Resources/salaries2017.csv"
data_df4 = pd.read_csv(csv_file4)
data_df4.head()
# Out:
#     Rk                     Player Pos   Tm    Cap Hit
# 0  1.0      Kirk Cousins\CousKi00  QB  WAS  $23943600
# 1  2.0  Trumaine Johnson\JohnTr05  CB  LAR  $16742400
# 2  3.0       Josh Norman\NormJo01  CB  WAS  $16500000
# 3  NaN        Von Miller\MillVo00  LB  DEN  $16500000
# 4  5.0    Justin Houston\HousJu00  LB  KAN  $16350000

# %%
data_df4.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Tm', 'Cap Hit'], dtype='object')

# %%
csv_file5 = "./Resources/salaries2018.csv"
data_df5 = pd.read_csv(csv_file5)
data_df5.head()
# Out:
#     Rk                      Player Pos   Tm     Salary
# 0  1.0       Kirk Cousins\CousKi00  QB  MIN  $22500000
# 1  2.0  Demarcus Lawrence\LawrDe00  DE  DAL  $17143000
# 2  NaN      Ezekiel Ansah\AnsaEz00  DE  DET  $17143000
# 3  4.0     Russell Wilson\WilsRu00  QB  SEA  $15500000
# 4  5.0    Calais Campbell\CampCa99  DE  JAX  $15000000

# %%
data_df5.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Tm', 'Salary'], dtype='object')

# %%
csv_file6 = "./Resources/salaries2019.csv"
data_df6 = pd.read_csv(csv_file6)
data_df6.head()
# Out:
#     Rk                   Player Pos   Tm        Salary
# 0  1.0    Kirk Cousins\CousKi00  QB  MIN  $27,500,000
# 1  2.0  Jameis Winston\WinsJa00  QB  TAM  $20,922,000
# 2  NaN  Marcus Mariota\MariMa01  QB  TEN  $20,922,000
# 3  4.0      Derek Carr\CarrDe02  QB  OAK  $19,900,000
# 4  5.0      Joe Flacco\FlacJo00  QB  DEN  $18,500,000

# %%
data_df6.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Tm', 'Salary'], dtype='object')

# %%
csv_file7 = "./Resources/state_centroids.csv"
data_df7 = pd.read_csv(csv_file7)
data_df7.head()
# Out:
#         State State Abbreviation  Latitude  Longitude
# 0     Alabama                 AL   32.7794   -86.8287
# 1      Alaska                 AK   64.0685  -152.2782
# 2     Arizona                 AZ   34.2744  -111.6602
# 3    Arkansas                 AR   34.8938   -92.4426
# 4  California                 CA   37.1841  -119.4696

# %%
new_data_df7 = data_df7.rename(columns = {"State Abbreviation" : "homeState"})

# %% [markdown]
# ## Clean DataFrame - Transform

# %%
# clean df1

new_data_df1 = data_df1[['passId', 'playId', 'teamId', 'playerId', 'passPosition',
       'passOutcomes', 'passDirection', 'passDepth', 'passLength', 'passAtt',
       'passComp', 'passTd']].copy()
new_data_df1.head()
# Out:
#      passId    playId  teamId  playerId passPosition passOutcomes  \
# 0  15154145  15088467    4500  20140062           QB     complete
# 1  15154146  15088472    4500  20140062           QB     complete
# 2  15154147  15088473    4500  20140062           QB     complete
# 3  15154148  15088474    4500  20140062           QB   incomplete
# 4  15154149  15088475    4500  20140062           QB   incomplete
#
#   passDirection passDepth  passLength  passAtt  passComp  passTd
# 0          left     short           0        1         1       0
# 1        middle     short          -1        1         1       0
# 2         right     short          -2        1         1       0
# 3        middle     short           5        1         0       0
# 4          left     short           6        1         0       0

# %%
# clean df2
new_data_df2 = data_df2[['playerId', 'draft', 'round', 'pick', 'draftTradeValue', 'draftTeam',
       'position', 'teamId', 'nameFirst', 'nameLast', 'nameFull', 'college', 'heightInches', 'weight', 'dob',
       'ageAtDraft', 'homeCity', 'homeState',
       'homeCountry']].copy()
new_data_df2.head()
# Out:
#    playerId  draft  round  pick  draftTradeValue draftTeam position  teamId  \
# 0  19770001   1977    1.0     1           3000.0        TB       RB    4900
# 1  19770002   1977    1.0     2           2600.0       DAL       RB    1200
# 2  19770003   1977    1.0     3           2200.0       CIN       DE     920
# 3  19770004   1977    1.0     4           1800.0       NYJ       OT    3430
# 4  19770005   1977    1.0     5           1700.0       NYG       DE    3410
#
#   nameFirst nameLast       nameFull     college  heightInches  weight  \
# 0     Ricky     Bell     Ricky Bell         USC          74.0   220.0
# 1      Tony  Dorsett   Tony Dorsett  Pittsburgh          71.0   192.0
# 2     Eddie  Edwards  Eddie Edwards  Miami (FL)          77.0   256.0
# 3    Marvin   Powell  Marvin Powell         USC          77.0   268.0
# 4      Gary    Jeter     Gary Jeter         USC          76.0   259.0
#
#           dob  ageAtDraft     homeCity homeState homeCountry
# ...

# %%
# adding lat long to df2
new_data_df2 = pd.merge(new_data_df2, new_data_df7, on='homeState', how='outer')
new_data_df2.head()
# Out:
#      playerId   draft  round  pick  draftTradeValue draftTeam position  \
# 0  19770001.0  1977.0    1.0   1.0           3000.0        TB       RB
# 1  19770008.0  1977.0    1.0   8.0           1400.0       CIN       DT
# 2  19770010.0  1977.0    1.0  10.0           1300.0        KC       DB
# 3  19770016.0  1977.0    1.0  16.0           1000.0        NE       DB
# 4  19770017.0  1977.0    1.0  17.0            950.0       CLV       LB
#
#    teamId nameFirst  nameLast  ... heightInches weight         dob  \
# 0  4900.0     Ricky      Bell  ...         74.0  220.0  1955-04-08
# 1   920.0    Wilson   Whitley  ...         75.0  265.0  1955-04-28
# 2  2310.0      Gary     Green  ...         71.0  187.0  1955-10-22
# 3  3200.0   Raymond  Clayborn  ...         72.0  186.0  1955-01-02
# 4  1050.0    Robert   Jackson  ...         73.0  230.0  1954-08-07
#
#    ageAtDraft     homeCity  homeState homeCountry  State Latitude Longitude
# ...

# %%
# Split Player Column into Player Name and Player ID Column

data_df3[['Player Name','Player ID']] = data_df3.Player.str.split('\\',expand=True,)
data_df3.head()
# Out:
#     Rk                       Player Pos   Tm    Cap Hit         Player Name  \
# 0  1.0  Ben Roethlisberger\RoetBe00  QB  PIT  $23950000  Ben Roethlisberger
# 1  2.0           Matt Ryan\RyanMa00  QB  ATL  $23750000           Matt Ryan
# 2  3.0          Joe Flacco\FlacJo00  QB  BAL  $22550000          Joe Flacco
# 3  4.0        Kirk Cousins\CousKi00  QB  WAS  $19953000        Kirk Cousins
# 4  5.0          Cam Newton\NewtCa00  QB  CAR  $19500000          Cam Newton
#
#   Player ID
# 0  RoetBe00
# 1  RyanMa00
# 2  FlacJo00
# 3  CousKi00
# 4  NewtCa00

# %%
data_df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Tm', 'Cap Hit', 'Player Name', 'Player ID'], dtype='object')

# %%
new_data_df3 = data_df3[['Rk', 'Pos', 'Tm', 'Cap Hit', 'Player Name']].copy()
new_data_df3.head()
# Out:
#     Rk Pos   Tm    Cap Hit         Player Name
# 0  1.0  QB  PIT  $23950000  Ben Roethlisberger
# 1  2.0  QB  ATL  $23750000           Matt Ryan
# 2  3.0  QB  BAL  $22550000          Joe Flacco
# 3  4.0  QB  WAS  $19953000        Kirk Cousins
# 4  5.0  QB  CAR  $19500000          Cam Newton

# %%
data_df4[['Player Name','Player ID']] = data_df4.Player.str.split('\\',expand=True,)
data_df4.head()
# Out:
#     Rk                     Player Pos   Tm    Cap Hit       Player Name  \
# 0  1.0      Kirk Cousins\CousKi00  QB  WAS  $23943600      Kirk Cousins
# 1  2.0  Trumaine Johnson\JohnTr05  CB  LAR  $16742400  Trumaine Johnson
# 2  3.0       Josh Norman\NormJo01  CB  WAS  $16500000       Josh Norman
# 3  NaN        Von Miller\MillVo00  LB  DEN  $16500000        Von Miller
# 4  5.0    Justin Houston\HousJu00  LB  KAN  $16350000    Justin Houston
#
#   Player ID
# 0  CousKi00
# 1  JohnTr05
# 2  NormJo01
# 3  MillVo00
# 4  HousJu00

# %%
data_df4.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Tm', 'Cap Hit', 'Player Name', 'Player ID'], dtype='object')

# %%
new_data_df4 = data_df4[['Rk', 'Pos', 'Tm', 'Cap Hit', 'Player Name']].copy()
new_data_df4.head()
# Out:
#     Rk Pos   Tm    Cap Hit       Player Name
# 0  1.0  QB  WAS  $23943600      Kirk Cousins
# 1  2.0  CB  LAR  $16742400  Trumaine Johnson
# 2  3.0  CB  WAS  $16500000       Josh Norman
# 3  NaN  LB  DEN  $16500000        Von Miller
# 4  5.0  LB  KAN  $16350000    Justin Houston

# %%
data_df5[['Player Name','Player ID']] = data_df5.Player.str.split('\\',expand=True,)
data_df5.head()
# Out:
#     Rk                      Player Pos   Tm     Salary        Player Name  \
# 0  1.0       Kirk Cousins\CousKi00  QB  MIN  $22500000       Kirk Cousins
# 1  2.0  Demarcus Lawrence\LawrDe00  DE  DAL  $17143000  Demarcus Lawrence
# 2  NaN      Ezekiel Ansah\AnsaEz00  DE  DET  $17143000      Ezekiel Ansah
# 3  4.0     Russell Wilson\WilsRu00  QB  SEA  $15500000     Russell Wilson
# 4  5.0    Calais Campbell\CampCa99  DE  JAX  $15000000    Calais Campbell
#
#   Player ID
# 0  CousKi00
# 1  LawrDe00
# 2  AnsaEz00
# 3  WilsRu00
# 4  CampCa99

# %%
data_df5.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Tm', 'Salary', 'Player Name', 'Player ID'], dtype='object')

# %%
new_data_df5 = data_df5[['Rk', 'Pos', 'Tm', 'Salary', 'Player Name']].copy()
new_data_df5.head()
# Out:
#     Rk Pos   Tm     Salary        Player Name
# 0  1.0  QB  MIN  $22500000       Kirk Cousins
# 1  2.0  DE  DAL  $17143000  Demarcus Lawrence
# 2  NaN  DE  DET  $17143000      Ezekiel Ansah
# 3  4.0  QB  SEA  $15500000     Russell Wilson
# 4  5.0  DE  JAX  $15000000    Calais Campbell

# %%
data_df6[['Player Name','Player ID']] = data_df6.Player.str.split('\\',expand=True,)
data_df6.head()
# Out:
#     Rk                   Player Pos   Tm        Salary     Player Name  \
# 0  1.0    Kirk Cousins\CousKi00  QB  MIN  $27,500,000     Kirk Cousins
# 1  2.0  Jameis Winston\WinsJa00  QB  TAM  $20,922,000   Jameis Winston
# 2  NaN  Marcus Mariota\MariMa01  QB  TEN  $20,922,000   Marcus Mariota
# 3  4.0      Derek Carr\CarrDe02  QB  OAK  $19,900,000       Derek Carr
# 4  5.0      Joe Flacco\FlacJo00  QB  DEN  $18,500,000       Joe Flacco
#
#   Player ID
# 0  CousKi00
# 1  WinsJa00
# 2  MariMa01
# 3  CarrDe02
# 4  FlacJo00

# %%
data_df6.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Tm', 'Salary', 'Player Name', 'Player ID'], dtype='object')

# %%
new_data_df6 = data_df6[['Rk', 'Pos', 'Tm', 'Salary', 'Player Name']].copy()
new_data_df6.head()
# Out:
#     Rk Pos   Tm        Salary     Player Name
# 0  1.0  QB  MIN  $27,500,000     Kirk Cousins
# 1  2.0  QB  TAM  $20,922,000   Jameis Winston
# 2  NaN  QB  TEN  $20,922,000   Marcus Mariota
# 3  4.0  QB  OAK  $19,900,000       Derek Carr
# 4  5.0  QB  DEN  $18,500,000       Joe Flacco

# %%
# Rename the column headers 

new_data_df3= new_data_df3.rename(columns= {
                                    "Rk": "salaryRk",
                                    "Pos": "position",
                                    "Tm": "team",
                                    "Cap Hit": "salary",
                                    "Player Name":"player_name"}) 

# Clean the data by dropping duplicates and setting the index
# new_data_df3.drop_duplicates("id", inplace=True)
# new_data_df.set_index("id", inplace=True)

new_data_df3.head()
# Out:
#    salaryRk position team     salary         player_name
# 0       1.0       QB  PIT  $23950000  Ben Roethlisberger
# 1       2.0       QB  ATL  $23750000           Matt Ryan
# 2       3.0       QB  BAL  $22550000          Joe Flacco
# 3       4.0       QB  WAS  $19953000        Kirk Cousins
# 4       5.0       QB  CAR  $19500000          Cam Newton

# %%
new_data_df4= new_data_df4.rename(columns= {
                                    "Rk": "salaryRk",
                                    "Pos": "position",
                                    "Tm": "team",
                                    "Cap Hit": "salary",
                                    "Player Name":"player_name"})
new_data_df4.head()
# Out:
#    salaryRk position team     salary       player_name
# 0       1.0       QB  WAS  $23943600      Kirk Cousins
# 1       2.0       CB  LAR  $16742400  Trumaine Johnson
# 2       3.0       CB  WAS  $16500000       Josh Norman
# 3       NaN       LB  DEN  $16500000        Von Miller
# 4       5.0       LB  KAN  $16350000    Justin Houston

# %%
new_data_df5= new_data_df5.rename(columns= {
                                    "Rk": "salaryRk",
                                    "Pos": "position",
                                    "Tm": "team",
                                    "Salary": "salary",
                                    "Player Name":"player_name"})
new_data_df5.head()
# Out:
#    salaryRk position team     salary        player_name
# 0       1.0       QB  MIN  $22500000       Kirk Cousins
# 1       2.0       DE  DAL  $17143000  Demarcus Lawrence
# 2       NaN       DE  DET  $17143000      Ezekiel Ansah
# 3       4.0       QB  SEA  $15500000     Russell Wilson
# 4       5.0       DE  JAX  $15000000    Calais Campbell

# %%
new_data_df6= new_data_df6.rename(columns= {
                                    "Rk": "salaryRk",
                                    "Pos": "position",
                                    "Tm": "team",
                                    "Salary": "salary",
                                    "Player Name":"player_name"})
new_data_df6.head()
# Out:
#    salaryRk position team        salary     player_name
# 0       1.0       QB  MIN  $27,500,000     Kirk Cousins
# 1       2.0       QB  TAM  $20,922,000   Jameis Winston
# 2       NaN       QB  TEN  $20,922,000   Marcus Mariota
# 3       4.0       QB  OAK  $19,900,000       Derek Carr
# 4       5.0       QB  DEN  $18,500,000       Joe Flacco

# %% [markdown]
# ###  Connect to local database/create connection

# %%
#rds_connection_string = "postgres:postgres@localhost:5432/NFL_db"
#engine = create_engine(f'postgresql://{rds_connection_string}')

#useing sqlite
engine = create_engine('sqlite:///NFL_db.sqlite', echo=False)
conn = engine.connect()

# %% [markdown]
# ## Use pandas to load csv converted DataFrame into database - Load

# %%
new_data_df1.to_sql(name='passer', con=engine, if_exists='append', index=True)

# %%
new_data_df2.to_sql(name='draft', con=engine, if_exists='replace', index=True)

# %%
new_data_df3.to_sql(name='salary_2016', con=engine, if_exists='append', index=True)

# %%
new_data_df4.to_sql(name='salary_2017', con=engine, if_exists='append', index=True)

# %%
new_data_df5.to_sql(name='salary_2018', con=engine, if_exists='append', index=True)

# %%
new_data_df6.to_sql(name='salary_2019', con=engine, if_exists='append', index=True)

# %% [markdown]
# ### Confirm data has been added by querying

# %%
engine.table_names()
# Out:
# ['draft', 'passer', 'salary_2016', 'salary_2017', 'salary_2018', 'salary_2019']

# %% [markdown]
# ## Query Databases to confirm Data transfer

# %%
pd.read_sql_query('select * from draft', con=engine).head()
# Out:
#    index    playerId   draft  round  pick  draftTradeValue draftTeam position  \
# 0      0  19770001.0  1977.0    1.0   1.0           3000.0        TB       RB
# 1      1  19770008.0  1977.0    1.0   8.0           1400.0       CIN       DT
# 2      2  19770010.0  1977.0    1.0  10.0           1300.0        KC       DB
# 3      3  19770016.0  1977.0    1.0  16.0           1000.0        NE       DB
# 4      4  19770017.0  1977.0    1.0  17.0            950.0       CLV       LB
#
#    teamId nameFirst  ... heightInches weight         dob  ageAtDraft  \
# 0  4900.0     Ricky  ...         74.0  220.0  1955-04-08   22.084932
# 1   920.0    Wilson  ...         75.0  265.0  1955-04-28   22.030137
# 2  2310.0      Gary  ...         71.0  187.0  1955-10-22   21.545205
# 3  3200.0   Raymond  ...         72.0  186.0  1955-01-02   22.347945
# 4  1050.0    Robert  ...         73.0  230.0  1954-08-07   22.753425
#
#       homeCity homeState  homeCountry  State Latitude Longitude
# ...

# %%
pd.read_sql_query('select * from passer', con=engine).head()
# Out:
#    index    passId    playId  teamId  playerId passPosition passOutcomes  \
# 0      0  15154145  15088467    4500  20140062           QB     complete
# 1      1  15154146  15088472    4500  20140062           QB     complete
# 2      2  15154147  15088473    4500  20140062           QB     complete
# 3      3  15154148  15088474    4500  20140062           QB   incomplete
# 4      4  15154149  15088475    4500  20140062           QB   incomplete
#
#   passDirection passDepth  passLength  passAtt  passComp  passTd
# 0          left     short           0        1         1       0
# 1        middle     short          -1        1         1       0
# 2         right     short          -2        1         1       0
# 3        middle     short           5        1         0       0
# 4          left     short           6        1         0       0

# %%
pd.read_sql_query('select * from salary_2016', con=engine).head()
# Out:
#    index  salaryRk position team     salary         player_name
# 0      0       1.0       QB  PIT  $23950000  Ben Roethlisberger
# 1      1       2.0       QB  ATL  $23750000           Matt Ryan
# 2      2       3.0       QB  BAL  $22550000          Joe Flacco
# 3      3       4.0       QB  WAS  $19953000        Kirk Cousins
# 4      4       5.0       QB  CAR  $19500000          Cam Newton

# %%
pd.read_sql_query('select * from salary_2017', con=engine).head()
# Out:
#    index  salaryRk position team     salary       player_name
# 0      0       1.0       QB  WAS  $23943600      Kirk Cousins
# 1      1       2.0       CB  LAR  $16742400  Trumaine Johnson
# 2      2       3.0       CB  WAS  $16500000       Josh Norman
# 3      3       NaN       LB  DEN  $16500000        Von Miller
# 4      4       5.0       LB  KAN  $16350000    Justin Houston

# %%
pd.read_sql_query('select * from salary_2018', con=engine).head()
# Out:
#    index  salaryRk position team     salary        player_name
# 0      0       1.0       QB  MIN  $22500000       Kirk Cousins
# 1      1       2.0       DE  DAL  $17143000  Demarcus Lawrence
# 2      2       NaN       DE  DET  $17143000      Ezekiel Ansah
# 3      3       4.0       QB  SEA  $15500000     Russell Wilson
# 4      4       5.0       DE  JAX  $15000000    Calais Campbell

# %%
pd.read_sql_query('select * from salary_2019', con=engine).head()
# Out:
#    index  salaryRk position team        salary     player_name
# 0      0       1.0       QB  MIN  $27,500,000     Kirk Cousins
# 1      1       2.0       QB  TAM  $20,922,000   Jameis Winston
# 2      2       NaN       QB  TEN  $20,922,000   Marcus Mariota
# 3      3       4.0       QB  OAK  $19,900,000       Derek Carr
# 4      4       5.0       QB  DEN  $18,500,000       Joe Flacco
